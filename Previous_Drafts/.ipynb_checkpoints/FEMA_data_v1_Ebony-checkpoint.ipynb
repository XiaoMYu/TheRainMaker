# %% [markdown]
# Has there been an increase in extreme weather events?
#
# According to our chart “Extreme One Day Precipitation Events from 1910-2015”, extreme precipitation events have filled an increased surface area of land. This could possibly mean that increase precipitation has led to more natural disasters.
#
# Has the temperature overtime been increasing?
#
# In our graphs showing temperature anomalies we have notice a trend of temperatures being consistently above average. In the 1996 to 2015 timeframe, each year the temperature has been above the 1901-2015 period average. This is even more stark when you look at our bar graph “Tends in Annual Average Temperatures 1901-2015”.
#
# What are the trends in FEMA disaster declarations.
#
# According to our data the vast majority of the disaster declarations made by FEMA have been for severe storms and hurricanes. There also has been a very clear increase in disaster declared by FEMA over the years.
#
# Problems that arose during our analysis of the data.
#
# One problem that arose when we did our data analysis was the question of the correlation between extreme one day precipitation events and the trends in annual temperature. When we plotted the graphs for these two datasets the data didn’t correlate in the way we thought it would. We thought there would be a correlation, but according to our graph there is little or no correlation. We think this is because of problematic units of measurement in the original CSV data files.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
fema_claims_xl = pd.ExcelFile("../Data/Yearly Paid Claims_FEMA.xlsx")
fema_funding_xl = pd.ExcelFile("../Data/Yearly FEMA funding.xlsx")
disasterinci = pd.ExcelFile("../Data/FEMA_Disaster incidents.xlsx")
precip_df = pd.read_csv("../Data/heavy_precip.csv")
temp_data = pd.read_csv("../Temperature Anomalies/Resources/Temperature_fig-1.csv")
disasterdec = pd.ExcelFile("../Data/FEMA_Disaster Declarations.xlsx")

# %%
#The total number of claims closed with payment for the given year.
#The total dollar amount paid (in billions) on closed claims for the given year.
nfip_pd = fema_claims_xl.parse("NFIP")
nfip_df = nfip_pd.groupby(["Year"]).sum()
nfip_df.reset_index(level=0, inplace=True)
#nfip = nfip_df[(nfip_df["Year"] >= 1996) & (nfip_df["Year"] <= 2015)]
nfip = nfip_df.rename(columns = {'NumberOfClaimsClosedWithPayment':'Number of Claims Closed'})
nfip = nfip.rename(columns = {'TotalPaid':'Total Paid on Closed Claims'})
nfip['Total Paid on Closed Claims'] = nfip['Total Paid on Closed Claims']/1000000000
nfip.head()
# Out:
#      Year  Number of Claims Closed  Total Paid on Closed Claims
# 0  1996.0                  46849.0                     0.635417
# 1  1997.0                  27063.0                     0.414132
# 2  1998.0                  52074.0                     0.706868
# 3  1999.0                  43385.0                     0.563194
# 4  2000.0                  14718.0                     0.180638

# %%
#The number of Flooding Episdoes for the Year.
noaa_df = fema_claims_xl.parse("NOAA")
noaa_pd = noaa_df.groupby(["Year"]).sum()
noaa_pd.pop("Lat")
noaa_pd.pop("Lon")
noaa = noaa_pd.rename(columns = {'NumEpisodes':'Flooding Episodes'})
noaa.reset_index(level=0, inplace=True)
noaa.head()
# Out:
#      Year  Flooding Episodes
# 0  1996.0               5633
# 1  1997.0               4658
# 2  1998.0               5461
# 3  1999.0               3873
# 4  2000.0               3536

# %%
#FEMA Funding in billions of Real 2010 Dollars
fema_funding = fema_funding_xl.parse("Data Source-CRS Report")
fema_funding.head()
# Out:
#    Year  Administration Request  Enacted Appropriation  \
# 0  2000                   3.521                  3.521
# 1  2001                   3.584                  1.964
# 2  2002                   1.660                  0.805
# 3  2003                   2.185                  0.948
# 4  2004                   2.258                  2.078
#
#    Emergency Supplemental   Total Enacted
# 0                    0.000           3.521
# 1                    0.000           1.964
# 2                    0.000           0.805
# 3                    1.690           2.638
# 4                    2.555           4.633

# %%
#Extreme One-Day Precipitation Events:  
#percentage of the land area of the contiguous 48 states where a much greater than normal portion 
#of total annual precipitation has come from extreme single-day precipitation events.
precip = precip_df[(precip_df['Year'] >= 1996) & (precip_df['Year'] <= 2015)]
precip.pop("9-year moving average")
precip.head()
# Out:
#     Year  Index value
# 86  1996        0.203
# 87  1997        0.112
# 88  1998        0.206
# 89  1999        0.153
# 90  2000        0.092

# %%
#Number of disaster incidents by year
d_incidents = disasterinci.parse("FEMA Declarations")
dis_inci = d_incidents[["Year", "Incident Type"]]
incidents_count = dis_inci.groupby(["Year"]).count()
incidents_count.reset_index(level=0, inplace=True)
incidents_count = incidents_count.rename(columns = {"Incident Type":'Number of Disasters Incidents'})
incidents_count.head()
# Out:
#    Year  Number of Disasters Incidents
# 0  1953                             13
# 1  1954                             17
# 2  1955                             18
# 3  1956                             16
# 4  1957                             16

# %%
#Temperature data: annual average temperatures in the contiguous 48 states have changed since 1901
bins = [1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
decades = [1900,1910,1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]
temp_data["Decade"] = pd.cut(temp_data["Year"], bins, labels=decades)
temp_data = temp_data[["Year", "Earth's surface"]]
temp_data = temp_data.rename(columns = {"Earth's surface":'Temperature anomaly'})
temp_data.head()
# Out:
#    Year  Temperature anomaly
# 0  1901                -0.15
# 1  1902                -0.43
# 2  1903                -1.40
# 3  1904                -0.86
# 4  1905                -1.02

# %%
temp_1996_2015_data = temp_data[(temp_data["Year"] >= 1996) & (temp_data["Year"] <= 2015)]
temp_1996_2015_data
# Out:
#      Year  Temperature anomaly
# 95   1996                -0.13
# 96   1997                 0.18
# 97   1998                 2.21
# 98   1999                 1.86
# 99   2000                 1.25
# 100  2001                 1.68
# 101  2002                 1.19
# 102  2003                 1.24
# 103  2004                 1.08
# 104  2005                 1.62
# 105  2006                 2.23
# 106  2007                 1.63
# 107  2008                 0.27
# 108  2009                 0.37
# 109  2010                 0.96
# 110  2011                 1.16
# 111  2012                 3.26
# 112  2013                 0.41
# 113  2014                 0.52
# 114  2015                 2.38

# %%
#Number of disaster declarations per year
fema_declarations = disasterdec.parse("FEMA Declarations")
fema_declarations['year'] = fema_declarations['Declaration Date'].dt.year
declaration_year = fema_declarations.groupby(["year"]).count()
declaration_year.reset_index(level=0, inplace=True)
disaster_declaration = declaration_year[["year", "Incident Type"]]
disaster_declaration = disaster_declaration.rename(columns = {"Incident Type":'Number of Disaster Declarations'})
disaster_declaration.head()
# Out:
#    year  Number of Disaster Declarations
# 0  1953                               13
# 1  1954                               17
# 2  1955                               18
# 3  1956                               16
# 4  1957                               16

# %%
incident_types = fema_declarations["Incident Type"].value_counts()
incident_types
# Out:
# Severe Storm(s)     15963
# Hurricane            9727
# Flood                9496
# Snow                 3620
# Fire                 2656
# Severe Ice Storm     1990
# Tornado              1430
# Drought              1292
# Coastal Storm         462
# Freezing              301
# Other                 297
# Typhoon               119
# Earthquake            105
# Volcano                50
# Fishing Losses         42
# Mud/Landslide          10
# Chemical                9
# Tsunami                 9
# Toxic Substances        9
# Human Cause             6
# Dam/Levee Break         6
# Terrorist               5
# Name: Incident Type, dtype: int64

# %%
incident_types = pd.DataFrame(incident_types)
incident_types = incident_types.rename(columns = {"" : "Disaster Type", "Incident Type": "Number of Disasters"})
incident_types
#Would like to add a column name to the first column.
# Out:
#                   Number of Disasters
# Severe Storm(s)                 15963
# Hurricane                        9727
# Flood                            9496
# Snow                             3620
# Fire                             2656
# Severe Ice Storm                 1990
# Tornado                          1430
# Drought                          1292
# Coastal Storm                     462
# Freezing                          301
# Other                             297
# Typhoon                           119
# Earthquake                        105
# Volcano                            50
# Fishing Losses                     42
# Mud/Landslide                      10
# Chemical                            9
# Tsunami                             9
# Toxic Substances                    9
# Human Cause                         6
# Dam/Levee Break                     6
# Terrorist                           5

# %%
fema_declarations_1996_2015 = fema_declarations[(fema_declarations['year'] >= 1996) & (fema_declarations['year'] <= 2015)]
fema_declarations_1996_2015
# Out:
#        Disaster Number IH Program Declared IA Program Declared  \
# 2661              4247                  No                  No
# 2662              4247                  No                  No
# 2663              4247                  No                  No
# 2664              4247                  No                  No
# 2665              4247                  No                  No
# 2666              4247                  No                  No
# 2667              4247                  No                  No
# 2668              4247                  No                  No
# 2669              4247                  No                  No
# 2670              4247                  No                  No
# 2671              4247                  No                  No
# 2672              4247                  No                  No
# 2673              4247                  No                  No
# 2674              4247                  No                  No
# 2675              4247                  No                  No
# 2676              4247                  No                  No
# 2677              4247                  No                  No
# 2678              4247                  No                  No
# 2679              4247                  No                  No
# 2680              4247                  No                  No
# 2681              4247                  No                  No
# 2682              4246                  No                  No
# 2683              4246                  No                  No
# 2684              4246                  No                  No
# 2685              4246                  No                  No
# 2686              4246                  No                  No
# 2687              4245                 Yes                  No
# 2688              4245                 Yes                  No
# 2689              4245                 Yes                  No
# 2690              4245                 Yes                  No
# ...                ...                 ...                 ...
# 33584             1075                  No                  No
# 33585             1078                  No                  No
# 33586             1078                  No                  No
# 33587             1078                  No                  No
# 33588             1078                  No                  No
# 33589             1077                  No                  No
# 33590             1077                  No                  No
# 33591             1077                  No                  No
# 33592             1077                  No                  No
# 33593             1077                  No                  No
# 33594             1077                  No                  No
# 33595             1079                  No                 Yes
# 33596             1079                  No                 Yes
# 33597             1079                  No                 Yes
# 33598             1079                  No                 Yes
# 33599             1079                  No                 Yes
# 33600             1079                  No                 Yes
# 33590                 Cheshire (County)  1996
# 33591                     Coos (County)  1996
# 33592                  Grafton (County)  1996
# 33593                Merrimack (County)  1996
# 33594                 Sullivan (County)  1996
# 33595                   Chelan (County)  1996
# 33596                  Clallam (County)  1996
# 33597                    Clark (County)  1996
# 33598                  Cowlitz (County)  1996
# 33599             Grays Harbor (County)  1996
# 33600                   Island (County)  1996
# 33601                Jefferson (County)  1996
# 33602                     King (County)  1996
# 33603                 Kittitas (County)  1996
# 33604                    Lewis (County)  1996
# 33605                    Mason (County)  1996
# 33606                  Pacific (County)  1996
# 33607                   Pierce (County)  1996
# 33608                   Skagit (County)  1996
# 33609                Snohomish (County)  1996
# 33610                 Thurston (County)  1996
# 33611                Wahkiakum (County)  1996
# 33612                  Whatcom (County)  1996
# 33613                   Yakima (County)  1996
#
# [30953 rows x 16 columns]

# %%
incident_types_1996_2015 = fema_declarations_1996_2015["Incident Type"].value_counts()
incident_types_1996_2015
# Out:
# Severe Storm(s)     13225
# Hurricane            7660
# Fire                 2583
# Flood                2509
# Snow                 1961
# Severe Ice Storm     1820
# Coastal Storm         379
# Other                 287
# Tornado               280
# Freezing               85
# Earthquake             63
# Typhoon                40
# Drought                29
# Chemical                9
# Tsunami                 9
# Mud/Landslide           7
# Terrorist               5
# Dam/Levee Break         1
# Volcano                 1
# Name: Incident Type, dtype: int64

# %%
incident_types_1996_2015 = pd.DataFrame(incident_types_1996_2015)
incident_types_1996_2015
# Out:
#                   Incident Type
# Severe Storm(s)           13225
# Hurricane                  7660
# Fire                       2583
# Flood                      2509
# Snow                       1961
# Severe Ice Storm           1820
# Coastal Storm               379
# Other                       287
# Tornado                     280
# Freezing                     85
# Earthquake                   63
# Typhoon                      40
# Drought                      29
# Chemical                      9
# Tsunami                       9
# Mud/Landslide                 7
# Terrorist                     5
# Dam/Levee Break               1
# Volcano                       1

# %%
#Extreme one-day precipitation events from 1996 to 2015.

plt.plot(precip["Year"],precip["Index value"])
plt.title("Extreme one-day precipitation events from 1996 to 2015")
plt.xlabel("Year")
plt.ylabel("Percent of Land Area")
plt.savefig("Extreme one-day precipitation events from 1996 to 2015")
plt.show()

# %%
precip_df
precip_df
# Out:
#      Year  Index value  9-year moving average
# 0    1910        0.078               0.097941
# 1    1911        0.148               0.108855
# 2    1912        0.116               0.115871
# 3    1913        0.082               0.120289
# 4    1914        0.167               0.121539
# 5    1915        0.125               0.114590
# 6    1916        0.101               0.100402
# 7    1917        0.052               0.089473
# 8    1918        0.078               0.089270
# 9    1919        0.125               0.095992
# 10   1920        0.089               0.102418
# 11   1921        0.111               0.106156
# 12   1922        0.106               0.106566
# 13   1923        0.127               0.101531
# 14   1924        0.088               0.092441
# 15   1925        0.050               0.085684
# 16   1926        0.099               0.084145
# 17   1927        0.101               0.083195
# 18   1928        0.068               0.078473
# 19   1929        0.076               0.071953
# 20   1930        0.057               0.069086
# 21   1931        0.061               0.073359
# 22   1932        0.073               0.082187
# 23   1933        0.138               0.088551
# 24   1934        0.065               0.090227
# 25   1935        0.073               0.092832
# 26   1936        0.110               0.099195
# 27   1937        0.117               0.102801
# 28   1938        0.127               0.097379
# 29   1939        0.054               0.086984
# ..    ...          ...                    ...
# 76   1986        0.133               0.104164
# 77   1987        0.095               0.102094
# 78   1988        0.085               0.101387
# 79   1989        0.087               0.105695
# 80   1990        0.149               0.110066
# 81   1991        0.124               0.108859
# 82   1992        0.056               0.107016
# 83   1993        0.122               0.114371
# 84   1994        0.114               0.131918
# 85   1995        0.169               0.150418
# 86   1996        0.203               0.161148
# 87   1997        0.112               0.162672
# 88   1998        0.206               0.156371
# 89   1999        0.153               0.143277
# 90   2000        0.092               0.128430
# 91   2001        0.114               0.119266
# 92   2002        0.133               0.118828
# 93   2003        0.096               0.127023
# 94   2004        0.127               0.142832
# 95   2005        0.204               0.161090
# 96   2006        0.156               0.174109
# 97   2007        0.197               0.177797
# 98   2008        0.203               0.173813
# 99   2009        0.105               0.166961
# 100  2010        0.215               0.160129
# 101  2011        0.138               0.153559
# 102  2012        0.123               0.149871
# 103  2013        0.168               0.154074
# 104  2014        0.131               0.167465
# 105  2015        0.210               0.185125
#
# [106 rows x 3 columns]

# %%
#Extreme one-day precipitation events from 1910 to 2015.

plt.plot(precip_df["Year"],precip_df["Index value"])
plt.title("Extreme one-day Precipitation Events from 1910 to 2015")
plt.xlabel("Year")
plt.ylabel("Percent of Land Area")
plt.savefig("Extreme one-day Precipitation Events from 1910 to 2015")
plt.show()

# %%
plt.plot(temp_data["Year"], temp_data["Temperature anomaly"])
plt.title("Trends in Annual Average Temperatures 1901 to 2015")
plt.xlabel("Years")
plt.ylabel("Temperature Anomaly Fahrenheit")
plt.savefig("Trends in Annual Average Temperatures 1901-2015-Line Graph")
plt.show()

# %%
plt.plot(temp_1996_2015_data["Year"],temp_1996_2015_data["Temperature anomaly"])
plt.title("Trends in Annual Average Temperatures 1996 to 2015")
plt.xlabel("Years")
plt.ylabel("Temperature Anomaly Fahrenheit")
plt.savefig("Trends in Annual Average Temperatures 1996-2015-Line Graph")
plt.show()

# %%
plt.plot(temp_data["Year"], temp_data["Temperature anomaly"])
plt.title("Trends in Annual Average Temperatures 1901-2015")
plt.xlabel("Years")
plt.ylabel("Temperature Anomaly Fahrenheit")
plt.savefig("Trends in Annual Average Temperatures 1901-2015")
plt.show()

# %%
#Trend in Average temperatures from 1901-2015 bar graph.
plt.figure(figsize=(20,10))
plt.title("Trends in Average Temperature 1901-2015")
plt.xlabel("years")
plt.ylabel("Temperature Anomaly Fahrenheit")
plt.bar(temp_data["Year"],temp_data["Temperature anomaly"])
plt.savefig("Trends in Average Temperature 1901-2015-Bar Graph ")
plt.show()

# %%
#Number of disasters type VS Disaster types (Bar Graph), 1953-2015.

incident_types.plot(kind="bar", facecolor="blue", figsize=(20,10))
plt.title("Number of Disaster Incidents by Type 1953 to 2015")
plt.xlabel("Disaster Type")
plt.ylabel("Number of Incidents")
plt.savefig("FEMA Disaster Declarations 1953-2015")
plt.show()

# %%
incident_types_1996_2015.plot(kind="bar",facecolor="blue", figsize=(20,10))
plt.title("Number of Disaster Incidents by Type 1996 to 2015")
plt.xlabel("Disaster Type")
plt.ylabel("Number of Incidents")
plt.savefig("FEMA Disaster Declarations 1996-2015")
plt.show()

# %%
plt.scatter(precip["Index value"],temp_1996_2015_data["Temperature anomaly"])
plt.savefig("Precipitation versus Temperature")
plt.show()

# %%
disasters_by_year = fema_declarations["year"].value_counts()
disasters_by_year
# Out:
# 2005    4736
# 2011    2680
# 2008    2300
# 2004    1853
# 1993    1705
# 2007    1640
# 2010    1635
# 1996    1622
# 2003    1574
# 2017    1529
# 1998    1497
# 1999    1419
# 2009    1265
# 2012    1261
# 1977    1160
# 2001    1148
# 2016    1132
# 2000    1082
# 2002    1040
# 2006     975
# 1997     919
# 2015     916
# 1973     863
# 2013     737
# 1994     676
# 2014     654
# 1991     623
# 1974     619
# 1990     610
# 1995     602
#         ...
# 1975     460
# 1978     440
# 1965     429
# 1992     379
# 1985     327
# 1986     285
# 1984     264
# 1970     221
# 1983     203
# 1980     200
# 1967     197
# 1971     171
# 1987     162
# 1968     162
# 1982     158
# 1964     136
# 1966     120
# 1981      52
# 1988      51
# 1962      22
# 1963      20
# 1955      18
# 1954      17
# 1956      16
# 1957      16
# 1953      13
# 1960      12
# 1961      12
# 1958       7
# 1959       7
# Name: year, Length: 65, dtype: int64

# %%
disasters_by_year = pd.DataFrame(disasters_by_year)
disasters_by_year
# Out:
#       year
# 2005  4736
# 2011  2680
# 2008  2300
# 2004  1853
# 1993  1705
# 2007  1640
# 2010  1635
# 1996  1622
# 2003  1574
# 2017  1529
# 1998  1497
# 1999  1419
# 2009  1265
# 2012  1261
# 1977  1160
# 2001  1148
# 2016  1132
# 2000  1082
# 2002  1040
# 2006   975
# 1997   919
# 2015   916
# 1973   863
# 2013   737
# 1994   676
# 2014   654
# 1991   623
# 1974   619
# 1990   610
# 1995   602
# ...    ...
# 1975   460
# 1978   440
# 1965   429
# 1992   379
# 1985   327
# 1986   285
# 1984   264
# 1970   221
# 1983   203
# 1980   200
# 1967   197
# 1971   171
# 1987   162
# 1968   162
# 1982   158
# 1964   136
# 1966   120
# 1981    52
# 1988    51
# 1962    22
# 1963    20
# 1955    18
# 1954    17
# 1956    16
# 1957    16
# 1953    13
# 1960    12
# 1961    12
# 1958     7
# 1959     7
#
# [65 rows x 1 columns]

# %%
disasters_by_year.plot(kind="bar", facecolor="blue",figsize=(20,10))
plt.title("Number of FEMA Disaster Delclarations by Year 1953-2015")
plt.xlabel("Years")
plt.ylabel("Number of Incidents")
plt.savefig("Number of FEMA Disaster Declarations 1953-2015")
plt.show()
