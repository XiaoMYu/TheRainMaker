# %%
#Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime

# %%
# Store file path.
file = ("Resources/data.gov.FEMADeclarations.10.16.17.xlsx")

xl = pd.ExcelFile("Resources/data.gov.FEMADeclarations.10.16.17.xlsx")

print(xl.sheet_names)
# Out:
# ['Instructions', 'MetaData', 'FEMA Declarations']

# %%
fema_declarations = xl.parse("FEMA Declarations")
fema_declarations
# Out:
#        Disaster Number IH Program Declared IA Program Declared  \
# 0                 4346                  No                  No
# 1                 4346                  No                  No
# 2                 4346                  No                  No
# 3                 4346                  No                  No
# 4                 4346                  No                  No
# 5                 4346                  No                  No
# 6                 4346                  No                  No
# 7                 4346                  No                  No
# 8                 4346                  No                  No
# 9                 4346                  No                  No
# 10                4346                  No                  No
# 11                4346                  No                  No
# 12                4346                  No                  No
# 13                4346                  No                  No
# ...

# %%
fema_declarations['year'] = fema_declarations['Declaration Date'].dt.year
fema_declarations
# Out:
#        Disaster Number IH Program Declared IA Program Declared  \
# 0                 4346                  No                  No
# 1                 4346                  No                  No
# 2                 4346                  No                  No
# 3                 4346                  No                  No
# 4                 4346                  No                  No
# 5                 4346                  No                  No
# 6                 4346                  No                  No
# 7                 4346                  No                  No
# 8                 4346                  No                  No
# 9                 4346                  No                  No
# 10                4346                  No                  No
# 11                4346                  No                  No
# 12                4346                  No                  No
# 13                4346                  No                  No
# ...

# %%
declartion_year = fema_declarations.groupby(["year"]).count()
declartion_year.reset_index(level=0, inplace=True)
declartion_year
# Out:
#     year  Disaster Number  IH Program Declared  IA Program Declared  \
# 0   1953               13                   13                   13
# 1   1954               17                   17                   17
# 2   1955               18                   18                   18
# 3   1956               16                   16                   16
# 4   1957               16                   16                   16
# 5   1958                7                    7                    7
# 6   1959                7                    7                    7
# 7   1960               12                   12                   12
# 8   1961               12                   12                   12
# 9   1962               22                   22                   22
# 10  1963               20                   20                   20
# 11  1964              136                  136                  136
# 12  1965              429                  429                  429
# ...

# %%
year_data = declartion_year[["year", "Incident Type"]]
year_data
# Out:
#     year  Incident Type
# 0   1953             13
# 1   1954             17
# 2   1955             18
# 3   1956             16
# 4   1957             16
# 5   1958              7
# 6   1959              7
# 7   1960             12
# 8   1961             12
# 9   1962             22
# 10  1963             20
# 11  1964            136
# 12  1965            429
# 13  1966            120
# 14  1967            197
# 15  1968            162
# 16  1969            505
# 17  1970            221
# 18  1971            171
# 19  1972            526
# 20  1973            863
# 21  1974            619
# 22  1975            460
# 23  1976            586
# 24  1977           1160
# 25  1978            440
# 26  1979            476
# 27  1980            200
# 28  1981             52
# 29  1982            158
# ..   ...            ...
# 35  1988             51
# 36  1989            462
# 37  1990            610
# 38  1991            623
# 39  1992            379
# 40  1993           1705
# ...
