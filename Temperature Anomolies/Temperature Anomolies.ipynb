# %%
# Dependencies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Store file path and read CSV file with the pandas library.

temp_data = pd.read_csv("Resources/Temperature_fig-1.csv")
temperature_1901_2015_data
# Out:
#      Year  Earth's surface Lower troposphere (measured by satellite) (UAH)  \
# 0    1901            -0.15                                            null
# 1    1902            -0.43                                            null
# 2    1903            -1.40                                            null
# 3    1904            -0.86                                            null
# 4    1905            -1.02                                            null
# 5    1906            -0.29                                            null
# 6    1907            -0.54                                            null
# 7    1908             0.06                                            null
# 8    1909            -0.59                                            null
# 9    1910             0.40                                            null
# 10   1911             0.01                                            null
# ...

# %%
# Create Bins.
#Bins are 1890-1900, 1900-1910, 1910-1920, 1920-1930, 1930-1940, 1940-1950, 1950-1960, 1960-1970, 1970-1980, 1980-1990, 1990-2000, 2000-2010, 2010-2020.

bins = [1890, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

decades = [1900,1910,1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020]

# %%
temperature_1901_2015_data["Decade"] = pd.cut(temperature_1901_2015_data["Year"], bins, labels=decades)
temperature_1901_2015_data.head()
# Out:
#    Year  Earth's surface Lower troposphere (measured by satellite) (UAH)  \
# 0  1901            -0.15                                            null
# 1  1902            -0.43                                            null
# 2  1903            -1.40                                            null
# 3  1904            -0.86                                            null
# 4  1905            -1.02                                            null
#
#   Lower troposphere (measured by satellite) (RSS) Decade
# 0                                            null   1910
# 1                                            null   1910
# 2                                            null   1910
# 3                                            null   1910
# 4                                            null   1910

# %%
x_axis = temperature_1901_2015_data["Year"]

# %%
plt.bar(x_axis, temperature_1901_2015_data["Earth's surface"])
plt.show()
